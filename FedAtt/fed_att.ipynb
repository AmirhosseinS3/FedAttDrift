# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import copy

from keras import Model, Sequential
from keras.optimizers import  Adam
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

# %%
def prepare_data(df_list, T=10):
    data = []
    masks = []
    for df in df_list:
        x = []
        y = []
        for i in range(len(fog_idxs)):
            inputrow = []
            outputrow = []
            for counter in range(0, len(df[df['Fog node'] == fog_idxs[i]])-T-1):
                inputrow.append(np.array(df[df['Fog node'] == fog_idxs[i]][feature_cols].iloc[counter:counter+T, :]))
                inputrow[-1][-1, -1] = 0.0
                outputrow.append(np.array(df[df['Fog node'] == fog_idxs[i]][label_cols].iloc[counter+T-1, :]))
            inputdf = np.array(inputrow)
            outputdf = np.array(outputrow)
            x.append(np.float32(inputdf))
            y.append(np.float32(outputdf))
        d = dict()
        d['x'] = np.array(x)
        d['y'] = np.array(y)
        sizes = [len(y[i]) for i in range(len(fog_idxs))]
        mask = np.equal(sizes, 0)
        data.append(d)
        masks.append(mask)
    return data, masks


def normalize(vec):
    max_val = max(vec)
    min_val = min(vec)
    return (vec - min_val) / (max_val - min_val)


class LocalModel(Model):
  def __init__(self, T):
    super(LocalModel, self).__init__()
    self.lstm1 = LSTM(100, input_shape=(T, len(feature_cols)))
    self.dense1 = Dense(100)
    self.dense2 = Dense(1, activation='sigmoid')

  def call(self, inputs):
    x = self.lstm1(inputs)
    x = self.dense1(x)
    x = self.dense2(x)
    return x


def softmax(x):
    return np.exp(x)/np.sum(np.exp(x), axis=0)


def fed_att(g_model, l_models, mask):
    g_model_next = copy.deepcopy(g_model)
    L = len(g_model.layers)
    K = len(l_models)
    g_lr = 0.001
    for l in range(L):
        s = np.zeros((K, L))
        for k in range(K):
            for i in range(len(g_model.layers[l].get_weights())):
                s[k, l] += np.linalg.norm(g_model.layers[l].get_weights()[i] - l_models[k].layers[l].get_weights()[i])
    att = softmax(s)
    for l in range(L):
        fed_att_g_weights = g_model.layers[l].get_weights()
        for k in range(K):
            for i in range(len(g_model.layers[l].get_weights())):
                fed_att_g_weights[i] -=  (1-np.array(mask, dtype=np.int32)[k]) * g_lr * att[k, l] * (g_model.layers[l].get_weights()[i] - l_models[k].layers[l].get_weights()[i])
        g_model_next.layers[l].set_weights(fed_att_g_weights)
    return g_model_next.get_weights()


def train_models_time_step(data, mask):
    loss = []
    [loss.append([]) for _ in fog_idxs]
    x_train = data['x']
    y_train = data['y']
    for epoch in range(GLOBAL_EPOCHS):
        for i in range(len(fog_idxs)):
            if not mask[i]:
                history = local_models[i].fit(x_train[i], y_train[i], epochs=LOCAL_EPOCHS, verbose=VERBOSE, batch_size=B)
                loss[i].append(history.history['loss'][0])
            if mask[i]:
                loss[i].append(0.0)
        global_weight = copy.deepcopy(fed_att(global_model, local_models, mask))
        for i in range(len(fog_idxs)):
            local_models[i].set_weights(global_weight)
    return loss

# %%
B = 32
T = 10
MAX_COST = 175
GLOBAL_EPOCHS = 10
LOCAL_EPOCHS = 1
VERBOSE = True

df = pd.read_csv('../data/trace/salman_avg.csv')
df = df[df['Cost'] < MAX_COST]
df['Cost'] = df['Cost']/300
fog_idxs = np.array(np.unique(df['Fog node']), dtype=np.int32)

df['Long'] = normalize(df['Long'])
df['Lat'] = normalize(df['Lat'])
df['CosTime'] = np.cos(df['TimeMin']/(60*24))
df['SinTime'] = np.sin(df['TimeMin']/(60*24))
feature_cols = ['Long', 'Lat', 'CosTime', 'SinTime', 'Cost']
label_cols = ['Cost']

# %%
global_model = LocalModel(T)
_ = global_model(tf.zeros((B, T, len(feature_cols))))
global_weight = global_model.get_weights()
global_model.compile(loss='mae', optimizer=Adam(0.001))

local_models = [LocalModel(T) for _ in fog_idxs]
for local_model in local_models:
    _ = local_model(tf.zeros((B, T, len(feature_cols))))
    local_model.compile(loss='mae', optimizer=Adam(0.001))
    local_model.set_weights(global_weight)

# %%
EXP = 1
df1 = copy.deepcopy(df.loc[df['TimeMin']>=0].loc[df['TimeMin']<200])
df2 = copy.deepcopy(df.loc[df['TimeMin']>=200].loc[df['TimeMin']<400])
df3 = copy.deepcopy(df.loc[df['TimeMin']>=400])

df2.loc[df2['Fog node']==16, 'Cost'] += 0.2

data, masks = prepare_data([df1, df2, df3])
loss1 = train_models_time_step(data[0], masks[0])
loss2 = train_models_time_step(data[1], masks[1])
loss3 = train_models_time_step(data[2], masks[2])

loss = np.zeros((3*GLOBAL_EPOCHS, len(fog_idxs)))
for i in range(len(fog_idxs)):
    loss[:, i] = np.array(loss1[i] + loss2[i] + loss3[i])
# Out:
# ======] - 0s 9ms/step - loss: 0.0314
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1364
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1400
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1489
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0842
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1316
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2859
# 34/34 [==============================] - 0s 8ms/step - loss: 0.1276
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1248
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2448
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2342
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1247
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1401
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1359
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0902
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0356
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1189
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1358
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1362
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0884
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1441
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2791
# 34/34 [==============================] - 0s 10ms/step - loss: 0.1367
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1275
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2448
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2310
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1335
# 13/13 [==============================] - 0s 11ms/step - loss: 0.1505
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1728
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0924
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0310
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1250
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1434
# 20/20 [==============================] - 0s 11ms/step - loss: 0.1394
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0877
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1349
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2734
# 34/34 [==============================] - 0s 10ms/step - loss: 0.1278
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1177
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2448
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2287
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1234
# 13/13 [==============================] - 0s 11ms/step - loss: 0.1452
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1419
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0924
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0331
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1215
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1371
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1323
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0828
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1381
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2722
# 34/34 [==============================] - 0s 9ms/step - loss: 0.1317
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1175
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2448
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2286
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1333
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1508
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1732
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0961
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0314
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1259
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1418
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1443
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0853
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1342
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2707
# 34/34 [==============================] - 0s 9ms/step - loss: 0.1330
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1211
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2448
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2287
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1234
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1486
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1383
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0928
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0330
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1229
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1372
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1392
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0820
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1375
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2704
# 34/34 [==============================] - 0s 9ms/step - loss: 0.1302
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1240
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2448
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2272
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1310
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1534
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1691
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0908
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0336
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1247
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1401
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1349
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0861
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1415
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2710
# 34/34 [==============================] - 0s 10ms/step - loss: 0.1302
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1236
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2448
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2270
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1218
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1439
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1410
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0940
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0327
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1254
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1343
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1355
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0854
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1406
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2703
# 34/34 [==============================] - 0s 10ms/step - loss: 0.1328
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1194
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2448
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2240
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1291
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1436
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1661
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0910
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0339
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1230
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1407
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1359
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0900
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1378
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2725
# 34/34 [==============================] - 0s 9ms/step - loss: 0.1308
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3948
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0562
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2607
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1192
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1238
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1543
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1672
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0899
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0675
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2550
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1247
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0960
# 43/43 [==============================] - 0s 9ms/step - loss: 0.1015
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0865
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1655
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1755
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2139
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0652
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2582
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1344
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1263
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1566
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1769
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0918
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0667
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2169
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1654
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0978
# 43/43 [==============================] - 0s 9ms/step - loss: 0.1016
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0969
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2150
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1679
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1956
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0584
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2566
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1196
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1301
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1488
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1791
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0862
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0667
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1989
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1251
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0944
# 43/43 [==============================] - 0s 10ms/step - loss: 0.1057
# 57/57 [==============================] - 1s 9ms/step - loss: 0.0952
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1832
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1660
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2004
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0596
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2555
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1330
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1249
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1593
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1787
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0881
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0670
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1972
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1659
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0988
# 43/43 [==============================] - 0s 9ms/step - loss: 0.1035
# 57/57 [==============================] - 1s 9ms/step - loss: 0.0941
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2063
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1655
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2066
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0580
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2548
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1223
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1253
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1570
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1760
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0918
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0674
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1985
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1320
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0963
# 43/43 [==============================] - 0s 10ms/step - loss: 0.1057
# 57/57 [==============================] - 1s 9ms/step - loss: 0.0959
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1789
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1563
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1973
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0590
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2543
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1220
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1247
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1647
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1768
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0928
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0690
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2046
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1561
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0965
# 43/43 [==============================] - 0s 9ms/step - loss: 0.1108
# 57/57 [==============================] - 1s 9ms/step - loss: 0.0929
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1958
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1871
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2080
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0596
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2540
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1266
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1254
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1446
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1741
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0976
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0676
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1983
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1238
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0960
# 43/43 [==============================] - 0s 10ms/step - loss: 0.1081
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0925
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1909
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1559
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1990
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0590
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2538
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1229
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1278
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1649
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1787
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0969
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0682
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2065
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1685
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0950
# 43/43 [==============================] - 0s 9ms/step - loss: 0.1046
# 57/57 [==============================] - 1s 9ms/step - loss: 0.0922
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1942
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1845
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2060
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0586
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2536
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1229
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1248
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1519
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1776
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0957
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0669
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2051
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1325
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0958
# 43/43 [==============================] - 0s 9ms/step - loss: 0.1015
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0943
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1899
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1523
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1991
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0580
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2537
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1299
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1320
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1655
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1790
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0954
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0697
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1993
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1690
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0976
# 43/43 [==============================] - 0s 11ms/step - loss: 0.1016
# 57/57 [==============================] - 1s 9ms/step - loss: 0.0952
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1931
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1904
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2074

# %%
i=16
l = loss[:, i]
plt.plot(np.arange(len(l)), l)
plt.show()
