# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import copy

from keras import Model, Sequential
from keras.optimizers import  Adam
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

# %%
def prepare_data(df_list, T=10):
    data = []
    masks = []
    for df in df_list:
        x = []
        y = []
        for i in range(len(fog_idxs)):
            inputrow = []
            outputrow = []
            for counter in range(0, len(df[df['Fog node'] == fog_idxs[i]])-T-1):
                inputrow.append(np.array(df[df['Fog node'] == fog_idxs[i]][feature_cols].iloc[counter:counter+T, :]))
                inputrow[-1][-1, -1] = 0.0
                outputrow.append(np.array(df[df['Fog node'] == fog_idxs[i]][label_cols].iloc[counter+T-1, :]))
            inputdf = np.array(inputrow)
            outputdf = np.array(outputrow)
            x.append(np.float32(inputdf))
            y.append(np.float32(outputdf))
        d = dict()
        d['x'] = np.array(x)
        d['y'] = np.array(y)
        sizes = [len(y[i]) for i in range(len(fog_idxs))]
        mask = np.equal(sizes, 0)
        data.append(d)
        masks.append(mask)
    return data, masks


def normalize(vec):
    max_val = max(vec)
    min_val = min(vec)
    return (vec - min_val) / (max_val - min_val)


class LocalModel(Model):

  def __init__(self, T):
    super(LocalModel, self).__init__()
    self.lstm1 = LSTM(100, input_shape=(T, len(feature_cols)))
    self.dense1 = Dense(100)
    self.dense2 = Dense(1, activation='sigmoid')

  def call(self, inputs):
    x = self.lstm1(inputs)
    x = self.dense1(x)
    x = self.dense2(x)
    return x

def fed_avg(models, data, mask):
    n = len(models[0].get_weights())
    fed_avg = [np.zeros(models[0].get_weights()[i].shape) for i in range(n)]
    C = 0
    for i in range(len(data)):
        C += len(data[i])
    for i in range(len(fog_idxs)):
        model = models[i]
        c = len(data[i])
        for i in range(n):
            fed_avg[i] += c/C*model.get_weights()[i]
    return fed_avg

def train_models_time_step(data, mask):
    loss = []
    [loss.append([]) for _ in fog_idxs]
    x_train = data['x']
    y_train = data['y']
    for epoch in range(GLOBAL_EPOCHS):
        for i in range(len(fog_idxs)):
            if not mask[i]:
                history = local_models[i].fit(x_train[i], y_train[i], epochs=LOCAL_EPOCHS, verbose=VERBOSE, batch_size=B)
                loss[i].append(history.history['loss'][0])
            if mask[i]:
                loss[i].append(0.0)
        global_weight = copy.deepcopy(fed_avg(local_models, y_train, mask))
        for i in range(len(fog_idxs)):
            local_models[i].set_weights(global_weight)
    return loss

# %%
B = 32
T = 10
MAX_COST = 175
GLOBAL_EPOCHS = 10
LOCAL_EPOCHS = 1
VERBOSE = True

df = pd.read_csv('../data/trace/salman_avg.csv')
df = df[df['Cost'] < MAX_COST]
df['Cost'] = df['Cost']/300
fog_idxs = np.array(np.unique(df['Fog node']), dtype=np.int32)

df['Long'] = normalize(df['Long'])
df['Lat'] = normalize(df['Lat'])
df['CosTime'] = np.cos(df['TimeMin']/(60*24))
df['SinTime'] = np.sin(df['TimeMin']/(60*24))
feature_cols = ['Long', 'Lat', 'CosTime', 'SinTime', 'Cost']
label_cols = ['Cost']

# %%
global_model = LocalModel(T)
_ = global_model(tf.zeros((B, T, len(feature_cols))))
global_weight = global_model.get_weights()
global_model.compile(loss='mae', optimizer=Adam(0.001))

local_models = [LocalModel(T) for _ in fog_idxs]
for local_model in local_models:
    _ = local_model(tf.zeros((B, T, len(feature_cols))))
    local_model.compile(loss='mae', optimizer=Adam(0.001))
    local_model.set_weights(global_weight)

# %%
EXP = 1
df1 = copy.deepcopy(df.loc[df['TimeMin']>=0].loc[df['TimeMin']<200])
df2 = copy.deepcopy(df.loc[df['TimeMin']>=200].loc[df['TimeMin']<400])
df3 = copy.deepcopy(df.loc[df['TimeMin']>=400])

df2.loc[df2['Fog node']==16, 'Cost'] += 0.2

data, masks = prepare_data([df1, df2, df3])
loss1 = train_models_time_step(data[0], masks[0])
loss2 = train_models_time_step(data[1], masks[1])
loss3 = train_models_time_step(data[2], masks[2])

loss = np.zeros((3*10, len(fog_idxs)))
for i in range(len(fog_idxs)):
    loss[:, i] = np.array(loss1[i] + loss2[i] + loss3[i])
# Out:
# ========] - 0s 13ms/step - loss: 0.2834
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0899
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2166
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3243
# 34/34 [==============================] - 0s 13ms/step - loss: 0.2867
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3504
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1580
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1955
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2309
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1735
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1721
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2073
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1381
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0240
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1648
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2075
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2406
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0878
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1956
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3202
# 34/34 [==============================] - 0s 10ms/step - loss: 0.2524
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3465
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1519
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1903
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2254
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1612
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1682
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1573
# 18/18 [==============================] - 0s 14ms/step - loss: 0.1270
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0262
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1383
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1721
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1357
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0857
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1636
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3140
# 34/34 [==============================] - 0s 10ms/step - loss: 0.1416
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3413
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1409
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1865
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2198
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1156
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1590
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1905
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0873
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0275
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1115
# 11/11 [==============================] - 0s 11ms/step - loss: 0.1292
# 20/20 [==============================] - 0s 11ms/step - loss: 0.1894
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0816
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1301
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3051
# 34/34 [==============================] - 0s 11ms/step - loss: 0.2042
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3375
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1162
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1829
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2114
# 14/14 [==============================] - 0s 10ms/step - loss: 0.
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0348
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1620
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1100
# 26/26 [==============================] - 0s 12ms/step - loss: 0.1226
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1675
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1411
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0744
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1040
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1985
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1307
# 49/49 [==============================] - 1s 14ms/step - loss: 0.1084
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1086
# 57/57 [==============================] - 1s 13ms/step - loss: 0.1237
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2341
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1732
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2461
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0389
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1569
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1081
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1475
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1603
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1381
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0691
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1074
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1935
# 18/18 [==============================] - 0s 14ms/step - loss: 0.1563
# 49/49 [==============================] - 1s 13ms/step - loss: 0.1275
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1485
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1178
# 12/12 [==============================] - 0s 16ms/step - loss: 0.2269
# 17/17 [==============================] - 0s 13ms/step - loss: 0.1670
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2406

# %%
# for i in range(len(fog_idxs)):
i=4
l = loss[:, i]
plt.plot(np.arange(len(l)), l)
plt.show()

# %%
EXP = 2
df1 = copy.deepcopy(df.loc[df['TimeMin']>=0].loc[df['TimeMin']<200])
df2 = copy.deepcopy(df.loc[df['TimeMin']>=200].loc[df['TimeMin']<400])
df3 = copy.deepcopy(df.loc[df['TimeMin']>=400])

df1.loc[df1['Fog node']==16, 'Cost'] += 0.2
df2.loc[df2['Fog node']==15, 'Cost'] += 0.2
data = prepare_data([df1, df2, df3])

# %%
EXP = 3
df1 = copy.deepcopy(df.loc[df['TimeMin']<300])
df2 = copy.deepcopy(df.loc[df['TimeMin']>=300])

df1.loc[df1['Fog node']==16, 'Cost'] += 0.1
df1.loc[df1['Fog node']==15, 'Cost'] += 0.4
data = prepare_data([df1, df2])

# %%
EXP = 4
df1 = copy.deepcopy(df.loc[df['TimeMin']>=0].loc[df['TimeMin']<200])
df2 = copy.deepcopy(df.loc[df['TimeMin']>=200].loc[df['TimeMin']<400])
df3 = copy.deepcopy(df.loc[df['TimeMin']>=400])

df1.loc[df1['Fog node']==16, 'Cost'] += 0.2*df1.loc[df1['Fog node']==16, 'TimeMin']/200
df2.loc[df2['Fog node']==16, 'Cost'] -= 0.2*(df2.loc[df2['Fog node']==16, 'TimeMin']-200)/200
data = prepare_data([df1, df2, df3])
